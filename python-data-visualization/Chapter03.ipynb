# %% [markdown]
# ### Chapter 3 Matplotlib Visualization
# Exercise 1

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker

# %%
src_file = Path.cwd() / 'data' / 'vehicles.csv'
image_dir = Path.cwd() / 'images'

# %%
df = pd.read_csv(src_file)
# Out:
# /tmp/ipykernel_78636/541733838.py:1: DtypeWarning: Columns (74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_file)

# %%
df.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  14.167143         0.0        0.0        0.0      19      0.0        0
# 1  27.046364         0.0        0.0        0.0       9      0.0        0
# 2  11.018889         0.0        0.0        0.0      23      0.0        0
# 3  27.046364         0.0        0.0        0.0      10      0.0        0
# 4  15.658421         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48671 entries, 0 to 48670
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        48671 non-null  float64
#  1   barrelsA08       48671 non-null  float64
#  2   charge120        48671 non-null  float64
#  3   charge240        48671 non-null  float64
#  4   city08           48671 non-null  int64
#  5   city08U          48671 non-null  float64
#  6   cityA08          48671 non-null  int64
#  7   cityA08U         48671 non-null  float64
#  8   cityCD           48671 non-null  float64
#  9   cityE            48671 non-null  float64
#  10  cityUF           48671 non-null  float64
#  11  co2              48671 non-null  int64
#  12  co2A             48671 non-null  int64
#  13  co2TailpipeAGpm  48671 non-null  float64
#  14  co2TailpipeGpm   48671 non-null  float64
#  15  comb08           48671 non-null  int64
# ...

# %%
# %matplotlib inline

# %%
plt.hist(df['comb08']);
plt.xlabel('Combined Fuel Economy')
plt.ylabel('Number of cars')
plt.title('Combined Fuel Economy (2000-2020)')
plt.show()

# %% [markdown]
# ### Using the object oriented API for matplotlib

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08']);

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08']);
ax.set_xlabel('Combined Fuel Economy (MPG)')
ax.set_ylabel('Number of cars')
ax.set_title('2000-2020')
# Out:
# Text(0.5, 1.0, '2000-2020')

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08']);
ax.set(xlabel='Combined Fuel Economy (MPG)', ylabel='Number of cars', title='2000-2020')
# Out:
# [Text(0.5, 0, 'Combined Fuel Economy (MPG)'),
#  Text(0, 0.5, 'Number of cars'),
#  Text(0.5, 1.0, '2000-2020')]

# %% [markdown]
# ### Customizing the plot

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50));

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), cumulative=True);

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), histtype='step', orientation='horizontal');

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'], range=(10,50), bins=10);

# %% [markdown]
# It is possible to get the values such as what the bins values are

# %%
fig, ax = plt.subplots()
n, bins, patches = ax.hist(df['comb08'], range=(10,50), bins=10)

# %%
n
# Out:
# array([ 2738., 10698., 16497.,  9983.,  4559.,  1778.,   593.,   278.,
#          102.,   140.])

# %%
bins
# Out:
# array([10., 14., 18., 22., 26., 30., 34., 38., 42., 46., 50.])

# %% [markdown]
# pathes represent the bars drawn and could be customized.

# %%
patches
# Out:
# <BarContainer object of 10 artists>
